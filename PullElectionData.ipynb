# %% [markdown]
# ## Collect House and Senate election outcomes from wikipedia
# This notbook uses the wikitables python library to grab election data from wikipedia.
# Election outcomes are then matched with FEC funding data

# %%
def importHouseData(wikipage,start,stop):
    from wikitables import import_tables
    import re
    import pandas as pd
    tables = import_tables(wikipage)
    States = ['Alabama','Alaska','Arizona' ,'Arkansas' ,'California' ,'Colorado','Connecticut',
              'Delaware' ,'Florida' ,'Georgia' ,'Hawaii' ,'Idaho' ,'Illinois' ,'Indiana','Iowa',
              'Kansas' ,'Kentucky' ,'Louisiana' ,'Maine','Maryland' ,'Massachusetts' ,'Michigan',
              'Minnesota' ,'Mississippi' ,'Missouri','Montana' ,'Nebraska','Nevada' ,
              'New Hampshire' ,'New Jersey' ,'New Mexico' ,'New York' ,'North Carolina' ,
              'North Dakota' ,'Ohio' ,'Oklahoma' ,'Oregon' ,'Pennsylvania' ,'Rhode Island' ,
              'South Carolina' ,'South Dakota' ,'Tennessee' ,'Texas' ,'Utah' ,'Vermont' ,
              'Virginia' ,'Washington' ,'West Virginia' ,'Wisconsin' ,'Wyoming']
    df = pd.DataFrame(columns=['State','District','Candidate','Vote%','Party'])
    ## parse the table
    for table in tables[start:stop]:
        ## get state from first row
        currState = 'FAILED'
        for state in States:
            if state in table.rows[0]['District'].value:
                currState = state
                States.remove(state)

        ## now parse candidates, parties, %vote
        district = 1
        for row in table.rows:
                #get line to be parsed
                fullString = '{Representative}'.format(**row)
                # regex out candidates
                candidates = filter(None,re.split('\xe2\x88\x9a |%|\d+\.\d+|<\d|\([A-Za-z0-9_/\- \.]+\) |\d|',fullString))
                if ' ' in candidates:
                    candidates.remove(' ')

                # regex out parties
                parties = re.findall('\([A-Za-z0-9_/\- \.]+\)',fullString)
                for p in parties: # make sure that wiki clarifications don't go in parties field
                    if 'politician' in p:
                        parties.remove(p)
                # regex %vote
                percentVotes = re.findall('\d+\.\d+|(?=<)\d|[0-9]+(?=%)',fullString)

                for cand,perc,part in map(None,candidates,percentVotes,parties):
                    if cand: #more parsing to remove wiki clarifications
                        cand = re.sub('\([\wA-Za-z. ]+\)', '', cand)
                    if part: # remove parenthesis on party
                        part = re.sub(r'\(|\)', '', part)
                    df.loc[len(df)] = [currState,district,cand,perc,part]
                    
                district+=1
    return df

# %%
house = importHouseData('United States House of Representatives elections, 2016',5,55)

# %%
def importSenateData(wikipage,start,stop):
    from wikitables import import_tables
    import re
    import pandas as pd
    tables = import_tables('United States Senate elections, 2016')
    States = ['Alabama','Alaska','Arizona' ,'Arkansas' ,'California' ,'Colorado','Connecticut',
              'Delaware' ,'Florida' ,'Georgia' ,'Hawaii' ,'Idaho' ,'Illinois' ,'Indiana','Iowa',
              'Kansas' ,'Kentucky' ,'Louisiana' ,'Maine','Maryland' ,'Massachusetts' ,'Michigan',
              'Minnesota' ,'Mississippi' ,'Missouri','Montana' ,'Nebraska','Nevada' ,
              'New Hampshire' ,'New Jersey' ,'New Mexico' ,'New York' ,'North Carolina' ,
              'North Dakota' ,'Ohio' ,'Oklahoma' ,'Oregon' ,'Pennsylvania' ,'Rhode Island' ,
              'South Carolina' ,'South Dakota' ,'Tennessee' ,'Texas' ,'Utah' ,'Vermont' ,
              'Virginia' ,'Washington' ,'West Virginia' ,'Wisconsin' ,'Wyoming']
    df = pd.DataFrame(columns=['State','District','Candidate','Vote%','Party'])
    ## parse the table
    for table in tables[start:stop]:
        ## now parse candidates, parties, %vote
        district = 0
        for row in table.rows:
            ## get state from first row
            currState = 'FAILED'
            for state in States:
                if state in row['Status'].value:
                    currState = state
                    States.remove(state)
                    #get line to be parsed
            fullString = '{Senator}'.format(**row)
            # regex out candidates
            candidates = filter(None,re.split('\xe2\x88\x9a |%|\d+\.\d+|<\d|\([A-Za-z0-9_/\- \.]+\) |\d|',fullString))
            if ' ' in candidates:
                candidates.remove(' ')

            # regex out parties
            parties = re.findall('\([A-Za-z0-9_/\- \.]+\)',fullString)
            for p in parties:
                if 'politician' in p:
                    parties.remove(p)
            # regex %vote
            percentVotes = re.findall('\d+\.\d+|(?=<)\d|[0-9]+(?=%)',fullString)

            for cand,perc,part in map(None,candidates,percentVotes,parties):
                if cand:
                        cand = re.sub('\([\wA-Za-z. ]+\)', '', cand)
                if part:
                    part = re.sub(r'\(|\)', '', part)
                df.loc[len(df)] = [currState,district,cand,perc,part]
                
        return df

# %%
senate = importSenateData('United States House of Representatives elections, 2016',8,9)
congress = pd.merge(senate,house,how='outer')
## noticed problem parsing arizona
congress.set_value(9,'Vote%',5)
congress.set_value(8,'Vote%',None)
# Out:
#               State  District                Candidate Vote%  \
# 0           Alabama       0.0          Richard Shelby   64.2
# 1           Alabama       0.0            Ron Crumpton   35.8
# 2            Alaska       0.0          Lisa Murkowski     44
# 3            Alaska       0.0              Joe Miller     29
# 4            Alaska       0.0          Margaret Stock     13
# 5            Alaska       0.0            Ray Metcalfe     12
# 6           Arizona       0.0             John McCain     53
# 7           Arizona       0.0         Ann Kirkpatrick     41
# 8           Arizona       0.0               Pat Quinn   None
# 9           Arizona       0.0              Gary Swing      5
# 10         Arkansas       0.0            John Boozman   59.7
# 11         Arkansas       0.0         Conner Eldridge   36.3
# 12         Arkansas       0.0           Frank Gilbert    4.0
# 13       California       0.0           Kamala Harris   61.8
# 14       California       0.0         Loretta Sanchez   38.2
# 15         Colorado       0.0          Michael Bennet   50.0
# 16         Colorado       0.0            Darryl Glenn   44.3
# 17         Colorado       0.0      Lily Tang Williams    3.6
# 18         Colorado       0.0             Arn Menconi    1.3
# 19      Connecticut       0.0      Richard Blumenthal   63.2
# 20      Connecticut       0.0              Dan Carter   34.6
# 21      Connecticut       0.0            Richard Lion    1.1
# 22      Connecticut       0.0            Jeff Russell    1.0
# 23          Florida       0.0             Marco Rubio   52.0
# 24          Florida       0.0          Patrick Murphy   44.3
# 25          Florida       0.0            Paul Stanton    2.1
# 26          Georgia       0.0          Johnny Isakson   54.8
# 27          Georgia       0.0           Jim Barksdale     41
# 28          Georgia       0.0           Allen Buckley   None
# 29           Hawaii       0.0            Brian Schatz   73.6
# ...             ...       ...                      ...   ...
# 1150  West Virginia       1.0          David McKinley   69.0
# 1151  West Virginia       1.0          Mike Manypenny   31.0
# 1152  West Virginia       2.0             Alex Mooney   58.2
# 1153  West Virginia       2.0               Mark Hunt   41.8
# 1154  West Virginia       3.0            Evan Jenkins   67.9
# 1155  West Virginia       3.0              Matt Detch   24.0
# 1156  West Virginia       3.0            Zane Lawhorn    8.1
# 1157      Wisconsin       1.0               Paul Ryan   65.0
# 1158      Wisconsin       1.0              Ryan Solen   30.2
# 1159      Wisconsin       1.0            Jason LeBeck    2.1
# 1160      Wisconsin       2.0              Mark Pocan   68.7
# 1161      Wisconsin       2.0            Peter Theron   31.2
# 1162      Wisconsin       3.0                Ron Kind   98.9
# 1163      Wisconsin       4.0              Gwen Moore   76.7
# 1164      Wisconsin       4.0              Andy Craig   11.2
# 1165      Wisconsin       4.0          Robert Raymond   11.7
# 1166      Wisconsin       5.0       Jim Sensenbrenner   66.7
# 1167      Wisconsin       5.0         Khary Penebaker   29.3
# 1168      Wisconsin       5.0              John Arndt    3.9
# 1169      Wisconsin       6.0          Glenn Grothman   57.2
# 1170      Wisconsin       6.0             Sarah Lloyd   37.3
# 1171      Wisconsin       6.0             Jeff Dahlke    5.5
# 1172      Wisconsin       7.0              Sean Duffy   61.7
# 1173      Wisconsin       7.0              Mary Hoeft   38.3
# 1174      Wisconsin       8.0          Mike Gallagher   62.7
# 1175      Wisconsin       8.0              Tom Nelson   37.3
# 1176        Wyoming       1.0              Liz Cheney   60.3
# 1177        Wyoming       1.0   Daniel Clyde Cummings    4.0
# 1178        Wyoming       1.0             Ryan Greene   29.2
# 1179        Wyoming       1.0       Lawrence Struempf    3.5
#
#                      Party
# 0               Republican
# 1               Democratic
# 2               Republican
# 3              Libertarian
# 4              Independent
# 5               Democratic
# 6               Republican
# 7               Democratic
# 8     independent/Write-in
# 9           Green/Write-in
# 10              Republican
# 11              Democratic
# 12             Libertarian
# 13              Democratic
# 14              Democratic
# 15              Democratic
# 16              Republican
# 17             Libertarian
# 18                   Green
# 19              Democratic
# 20              Republican
# 21             Libertarian
# 22                   Green
# 23              Republican
# 24              Democratic
# 25             Libertarian
# 26              Republican
# 27              Democratic
# 28             Libertarian
# 29              Democratic
# ...                    ...
# 1150            Republican
# 1151            Democratic
# 1152            Republican
# 1153            Democratic
# 1154            Republican
# 1155            Democratic
# 1156           Libertarian
# 1157            Republican
# 1158            Democratic
# 1159           Libertarian
# 1160            Democratic
# 1161            Republican
# 1162            Democratic
# 1163            Democratic
# 1164           Libertarian
# 1165           Independent
# 1166            Republican
# 1167            Democratic
# 1168           Libertarian
# 1169            Republican
# 1170            Democratic
# 1171           Independent
# 1172            Republican
# 1173            Democratic
# 1174            Republican
# 1175            Democratic
# 1176            Republican
# 1177          Constitution
# 1178            Democratic
# 1179           Libertarian
#
# [1180 rows x 5 columns]

# %%
import pandas as pd
# this csv was acquired here http://www.fec.gov/data/CandidateSummary.do?format=html
# The resulting data is loaded into a google doc for collaborators
googleDoc = pd.read_csv('ElectionOutcomes.csv')
googleDoc.head()
# Out:
#           ID            Candidate Party State Code   State  District  Outcome  \
# 0  H6AK00045      YOUNG, DONALD E   REP         AK  Alaska         0     50.3
# 1  S8AK00082  METCALFE, RAY HOMER   DEM         AK  Alaska         0      NaN
# 2  S4AK00099      MURKOWSKI, LISA   REP         AK  Alaska         0     44.0
# 3  S6AK00144         LOCHNER, BOB   REP         AK  Alaska         0      NaN
# 4  S6AK00151      STOCK, MARGARET   IND         AK  Alaska         0      NaN
#
#    Senate? (0/1)  Checked? (0/1)
# 0            0.0               0
# 1            NaN               0
# 2            1.0               0
# 3            NaN               0
# 4            NaN               0

# %%
import re
import numpy as np
## I want to match candidates based on state, then candidate name
States = ['Alabama','Alaska','Arizona' ,'Arkansas' ,'California' ,'Colorado','Connecticut',
              'Delaware' ,'Florida' ,'Georgia' ,'Hawaii' ,'Idaho' ,'Illinois' ,'Indiana','Iowa',
              'Kansas' ,'Kentucky' ,'Louisiana' ,'Maine','Maryland' ,'Massachusetts' ,'Michigan',
              'Minnesota' ,'Mississippi' ,'Missouri','Montana' ,'Nebraska','Nevada' ,
              'New Hampshire' ,'New Jersey' ,'New Mexico' ,'New York' ,'North Carolina' ,
              'North Dakota' ,'Ohio' ,'Oklahoma' ,'Oregon' ,'Pennsylvania' ,'Rhode Island' ,
              'South Carolina' ,'South Dakota' ,'Tennessee' ,'Texas' ,'Utah' ,'Vermont' ,
              'Virginia' ,'Washington' ,'West Virginia' ,'Wisconsin' ,'Wyoming']

for state in States:
    # select only current state
    distFund = googleDoc.loc[funding['State']==state]
    distCong = congress.loc[congress['State']==state]
    for i,cong in distCong.iterrows():
        # for each congressional candidate ...
        nameList = [x.upper() for x in filter(None,re.split(' ',cong['Candidate']))]
        counter = [0]*len(distFund)
        iFund=0
        # attempt to match name to fundraisers ...
        for i,fund in distFund.iterrows():
            for name in nameList:
                if name in fund['Candidate']:
                    counter[iFund]+=1
            iFund+=1
        # if "strong" match: update the fundraising df to reflect election outcome
        if sum([int(c==max(counter)) for c in counter])==1:
            iFund = distFund.index.values[np.argmax(counter)]
            googleDoc.set_value(iFund,'Outcome', cong['Vote%'])
            
googleDoc.to_csv('googleDoc.csv')
